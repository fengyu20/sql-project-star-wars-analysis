# %%
# import required modules
import sqlite3
import pandas as pd

# %%
# create a connection 
conn = sqlite3.connect('star_wars.db')

# %%
pd.read_sql(
    '''
        SELECT 
            *
        FROM 
            people
    ''', 
    conn
)
# Out:
#                name birth_year      eye_color  gender hair_color height mass  \
# 0    Luke Skywalker      19BBY           blue    male      blond    172   77
# 1             C-3PO     112BBY         yellow     n/a        n/a    167   75
# 2             R2-D2      33BBY            red     n/a        n/a     96   32
# 3       Darth Vader    41.9BBY         yellow    male       none    202  136
# 4       Leia Organa      19BBY          brown  female      brown    150   49
# ..              ...        ...            ...     ...        ...    ...  ...
# 77         Grievous    unknown  green, yellow    male       none    216  159
# 78          Tarfful    unknown           blue    male      brown    234  136
# 79  Raymus Antilles    unknown          brown    male      brown    188   79
# 80        Sly Moore    unknown          white  female       none    178   48
# 81       Tion Medon    unknown          black    male       none    206   80
#
# ...
