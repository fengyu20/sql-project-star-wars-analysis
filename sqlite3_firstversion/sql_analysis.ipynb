# %% [markdown]
# ## 0. Understanding Data

# %%
# import required modules
import sqlite3
import pandas as pd

# %%
# create a connection 
conn = sqlite3.connect('star_wars.db')

# %%
# take a look at the stored tables
tables = ['people', 'films', 'starships', 'vehicles', 'species', 'planets']

for table in tables:
    display(table)
    display(pd.read_sql(f'SELECT * FROM {table} LIMIT 1', conn))
# Out:
# 'people'
#              name birth_year eye_color gender hair_color height mass  \
# 0  Luke Skywalker      19BBY      blue   male      blond    172   77
#
#   skin_color  homeworld                                              films  \
# 0       fair          1  ["https://swapi.dev/api/films/1/", "https://sw...
#
#   species                                          starships  \
# 0      []  ["https://swapi.dev/api/starships/12/", "https...
#
#                                             vehicles  \
# 0  ["https://swapi.dev/api/vehicles/14/", "https:...
#
#                                url                      created  \
# 0  https://swapi.dev/api/people/1/  2014-12-09T13:50:51.644000Z
#
#                         edited  unique_id
# 0  2014-12-20T21:17:56.891000Z          1
# 'films'
#         title  episode_id                                      opening_crawl  \
# 0  A New Hope           4  It is a period of civil war.\r\nRebel spaceshi...
#
#        director                   producer release_date  \
# 0  George Lucas  Gary Kurtz, Rick McCallum   1977-05-25
#
#                                              species  \
# 0  ["https://swapi.dev/api/species/1/", "https://...
#
#                                            starships  \
# 0  ["https://swapi.dev/api/starships/2/", "https:...
#
#                                             vehicles  \
# 0  ["https://swapi.dev/api/vehicles/4/", "https:/...
#
#                                           characters  \
# 0  ["https://swapi.dev/api/people/1/", "https://s...
#
#                                              planets  \
# 0  ["https://swapi.dev/api/planets/1/", "https://...
#
#                               url                      created  \
# 0  https://swapi.dev/api/films/1/  2014-12-10T14:23:31.880000Z
#
#                         edited  unique_id
# 0  2014-12-20T19:49:45.256000Z          1
# 'starships'
#             name          model starship_class  \
# 0  CR90 corvette  CR90 corvette       corvette
#
#                         manufacturer cost_in_credits length    crew  \
# 0  Corellian Engineering Corporation         3500000    150  30-165
#
#   passengers max_atmosphering_speed hyperdrive_rating MGLT cargo_capacity  \
# 0        600                    950               2.0   60        3000000
#
#   consumables                                              films pilots  \
# 0      1 year  ["https://swapi.dev/api/films/1/", "https://sw...     []
#
#                                   url                      created  \
# 0  https://swapi.dev/api/starships/2/  2014-12-10T14:20:33.369000Z
#
#                         edited  unique_id
# 0  2014-12-20T21:23:49.867000Z          2
# 'vehicles'
#            name           model vehicle_class                 manufacturer  \
# 0  Sand Crawler  Digger Crawler       wheeled  Corellia Mining Corporation
#
#   length cost_in_credits crew passengers max_atmosphering_speed  \
# 0  36.8           150000   46         30                     30
#
#   cargo_capacity consumables  \
# 0          50000    2 months
#
#                                                films pilots  \
# 0  ["https://swapi.dev/api/films/1/", "https://sw...     []
#
#                                  url                      created  \
# 0  https://swapi.dev/api/vehicles/4/  2014-12-10T15:36:25.724000Z
#
#                         edited  unique_id
# 0  2014-12-20T21:30:21.661000Z          4
# 'species'
#     name average_height average_lifespan classification designation  \
# 0  Human            180              120         mammal    sentient
#
#                                eye_colors                hair_colors  \
# 0  brown, blue, green, hazel, grey, amber  blonde, brown, black, red
#
#    homeworld        language                        skin_colors  \
# 0        9.0  Galactic Basic  caucasian, black, asian, hispanic
#
#                                               people  \
# 0  ["https://swapi.dev/api/people/66/", "https://...
#
#                                                films  \
# 0  ["https://swapi.dev/api/films/1/", "https://sw...
#
#                                 url                      created  \
# 0  https://swapi.dev/api/species/1/  2014-12-10T13:52:11.567000Z
#
#                         edited  unique_id
# 0  2014-12-20T21:36:42.136000Z          1
# 'planets'
#        name diameter rotation_period orbital_period     gravity population  \
# 0  Tatooine    10465              23            304  1 standard     200000
#
#   climate terrain surface_water  \
# 0    arid  desert             1
#
#                                            residents  \
# 0  ["https://swapi.dev/api/people/1/", "https://s...
#
#                                                films  \
# 0  ["https://swapi.dev/api/films/1/", "https://sw...
#
#                                 url                      created  \
# 0  https://swapi.dev/api/planets/1/  2014-12-09T13:50:49.641000Z
#
#                         edited  unique_id
# 0  2014-12-20T20:58:18.411000Z          1

# %% [markdown]
# 1. Findings:
#     - To join these tables, we need to parse the links in the relevant column.
#     - For example, for the table `people`, a single person might appear in several movies, which is an array: `"https://swapi.dev/api/films/1/", "https://sw...`
# 2. Temporary Solution:
#     - Add a column named `unique_id` could be extracted from `url` column.
#     - As `homeworld` column only contains a single link, we could get the planet_id in `homework` column to join tables.
# 3. Solution:
#     - For sqlite3, the data type does not support lists, so we could shift to PostgreSQL to do the future data analysis.

# %%
# temporary solution to update unique_id and homework column
# tried a sql implementation and found out pandas is more intuitive
def extract_id(url):
    if pd.isnull(url) or not isinstance(url, str):
        return url
    return int(url.strip('/').split('/')[-1])


with sqlite3.connect('star_wars.db') as conn:
    for table in tables:
        df = pd.read_sql(f'select * from {table}', conn)
        
        #create unique_id column for each table
        df['unique_id'] = df['url'].apply(extract_id)

        # update homeworld column from url to id
        if 'homeworld' in df.columns:
            df['homeworld'] = df['homeworld'].apply(extract_id)
        
        df.to_sql(table, conn, if_exists='replace', index=False)

# %%
# take a look at the updated tables
for table in tables:
    display(table)
    display(pd.read_sql(f'SELECT * FROM {table} LIMIT 10', conn))
# Out:
# 'people'
#                  name birth_year  eye_color  gender     hair_color height  \
# 0      Luke Skywalker      19BBY       blue    male          blond    172
# 1               C-3PO     112BBY     yellow     n/a            n/a    167
# 2               R2-D2      33BBY        red     n/a            n/a     96
# 3         Darth Vader    41.9BBY     yellow    male           none    202
# 4         Leia Organa      19BBY      brown  female          brown    150
# 5           Owen Lars      52BBY       blue    male    brown, grey    178
# 6  Beru Whitesun lars      47BBY       blue  female          brown    165
# 7               R5-D4    unknown        red     n/a            n/a     97
# 8   Biggs Darklighter      24BBY      brown    male          black    183
# 9      Obi-Wan Kenobi      57BBY  blue-gray    male  auburn, white    182
#
#   mass   skin_color  homeworld  \
# 0   77         fair          1
# 1   75         gold          1
# 2   32  white, blue          8
# 3  136        white          1
# 4   49        light          2
# 5  120        light          1
# 6   75        light          1
# 7   32   white, red          1
# 8   84        light          1
# 9   77         fair         20
#
#                                                films  \
# 0  ["https://swapi.dev/api/films/1/", "https://sw...
# 1  ["https://swapi.dev/api/films/1/", "https://sw...
# 2  ["https://swapi.dev/api/films/1/", "https://sw...
# 3  ["https://swapi.dev/api/films/1/", "https://sw...
# 4  ["https://swapi.dev/api/films/1/", "https://sw...
# 5  ["https://swapi.dev/api/films/1/", "https://sw...
# 6  ["https://swapi.dev/api/films/1/", "https://sw...
# 7                 ["https://swapi.dev/api/films/1/"]
# 8                 ["https://swapi.dev/api/films/1/"]
# 9  ["https://swapi.dev/api/films/1/", "https://sw...
#
#                                 species  \
# 0                                    []
# 1  ["https://swapi.dev/api/species/2/"]
# 2  ["https://swapi.dev/api/species/2/"]
# 3                                    []
# 4                                    []
# 5                                    []
# 6                                    []
# 7  ["https://swapi.dev/api/species/2/"]
# 8                                    []
# 9                                    []
#
#                                            starships  \
# 0  ["https://swapi.dev/api/starships/12/", "https...
# 1                                                 []
# 2                                                 []
# 3            ["https://swapi.dev/api/starships/13/"]
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8            ["https://swapi.dev/api/starships/12/"]
# 9  ["https://swapi.dev/api/starships/48/", "https...
#
#                                             vehicles  \
# 0  ["https://swapi.dev/api/vehicles/14/", "https:...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4             ["https://swapi.dev/api/vehicles/30/"]
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8                                                 []
# 9             ["https://swapi.dev/api/vehicles/38/"]
#
#                                 url                      created  \
# 0   https://swapi.dev/api/people/1/  2014-12-09T13:50:51.644000Z
# 1   https://swapi.dev/api/people/2/  2014-12-10T15:10:51.357000Z
# 2   https://swapi.dev/api/people/3/  2014-12-10T15:11:50.376000Z
# 3   https://swapi.dev/api/people/4/  2014-12-10T15:18:20.704000Z
# 4   https://swapi.dev/api/people/5/  2014-12-10T15:20:09.791000Z
# 5   https://swapi.dev/api/people/6/  2014-12-10T15:52:14.024000Z
# 6   https://swapi.dev/api/people/7/  2014-12-10T15:53:41.121000Z
# 7   https://swapi.dev/api/people/8/  2014-12-10T15:57:50.959000Z
# 8   https://swapi.dev/api/people/9/  2014-12-10T15:59:50.509000Z
# 9  https://swapi.dev/api/people/10/  2014-12-10T16:16:29.192000Z
#
#                         edited  unique_id
# 0  2014-12-20T21:17:56.891000Z          1
# 1  2014-12-20T21:17:50.309000Z          2
# 2  2014-12-20T21:17:50.311000Z          3
# 3  2014-12-20T21:17:50.313000Z          4
# 4  2014-12-20T21:17:50.315000Z          5
# 5  2014-12-20T21:17:50.317000Z          6
# 6  2014-12-20T21:17:50.319000Z          7
# 7  2014-12-20T21:17:50.321000Z          8
# 8  2014-12-20T21:17:50.323000Z          9
# 9  2014-12-20T21:17:50.325000Z         10
# 'films'
#                      title  episode_id  \
# 0               A New Hope           4
# 1  The Empire Strikes Back           5
# 2       Return of the Jedi           6
# 3       The Phantom Menace           1
# 4     Attack of the Clones           2
# 5      Revenge of the Sith           3
#
#                                        opening_crawl          director  \
# 0  It is a period of civil war.\r\nRebel spaceshi...      George Lucas
# 1  It is a dark time for the\r\nRebellion. Althou...    Irvin Kershner
# 2  Luke Skywalker has returned to\r\nhis home pla...  Richard Marquand
# 3  Turmoil has engulfed the\r\nGalactic Republic....      George Lucas
# 4  There is unrest in the Galactic\r\nSenate. Sev...      George Lucas
# 5  War! The Republic is crumbling\r\nunder attack...      George Lucas
#
#                                            producer release_date  \
# 0                         Gary Kurtz, Rick McCallum   1977-05-25
# 1                         Gary Kurtz, Rick McCallum   1980-05-17
# 2  Howard G. Kazanjian, George Lucas, Rick McCallum   1983-05-25
# 3                                     Rick McCallum   1999-05-19
# 4                                     Rick McCallum   2002-05-16
# 5                                     Rick McCallum   2005-05-19
#
#                                              species  \
# 0  ["https://swapi.dev/api/species/1/", "https://...
# 1  ["https://swapi.dev/api/species/1/", "https://...
# 2  ["https://swapi.dev/api/species/1/", "https://...
# 3  ["https://swapi.dev/api/species/1/", "https://...
# 4  ["https://swapi.dev/api/species/1/", "https://...
# 5  ["https://swapi.dev/api/species/1/", "https://...
#
#                                            starships  \
# 0  ["https://swapi.dev/api/starships/2/", "https:...
# 1  ["https://swapi.dev/api/starships/3/", "https:...
# 2  ["https://swapi.dev/api/starships/2/", "https:...
# 3  ["https://swapi.dev/api/starships/31/", "https...
# 4  ["https://swapi.dev/api/starships/21/", "https...
# 5  ["https://swapi.dev/api/starships/2/", "https:...
#
#                                             vehicles  \
# 0  ["https://swapi.dev/api/vehicles/4/", "https:/...
# 1  ["https://swapi.dev/api/vehicles/8/", "https:/...
# 2  ["https://swapi.dev/api/vehicles/8/", "https:/...
# 3  ["https://swapi.dev/api/vehicles/33/", "https:...
# 4  ["https://swapi.dev/api/vehicles/4/", "https:/...
# 5  ["https://swapi.dev/api/vehicles/33/", "https:...
#
#                                           characters  \
# 0  ["https://swapi.dev/api/people/1/", "https://s...
# 1  ["https://swapi.dev/api/people/1/", "https://s...
# 2  ["https://swapi.dev/api/people/1/", "https://s...
# 3  ["https://swapi.dev/api/people/2/", "https://s...
# 4  ["https://swapi.dev/api/people/2/", "https://s...
# 5  ["https://swapi.dev/api/people/1/", "https://s...
#
#                                              planets  \
# 0  ["https://swapi.dev/api/planets/1/", "https://...
# 1  ["https://swapi.dev/api/planets/4/", "https://...
# 2  ["https://swapi.dev/api/planets/1/", "https://...
# 3  ["https://swapi.dev/api/planets/1/", "https://...
# 4  ["https://swapi.dev/api/planets/1/", "https://...
# 5  ["https://swapi.dev/api/planets/1/", "https://...
#
#                               url                      created  \
# 0  https://swapi.dev/api/films/1/  2014-12-10T14:23:31.880000Z
# 1  https://swapi.dev/api/films/2/  2014-12-12T11:26:24.656000Z
# 2  https://swapi.dev/api/films/3/  2014-12-18T10:39:33.255000Z
# 3  https://swapi.dev/api/films/4/  2014-12-19T16:52:55.740000Z
# 4  https://swapi.dev/api/films/5/  2014-12-20T10:57:57.886000Z
# 5  https://swapi.dev/api/films/6/  2014-12-20T18:49:38.403000Z
#
#                         edited  unique_id
# 0  2014-12-20T19:49:45.256000Z          1
# 1  2014-12-15T13:07:53.386000Z          2
# 2  2014-12-20T09:48:37.462000Z          3
# 3  2014-12-20T10:54:07.216000Z          4
# 4  2014-12-20T20:18:48.516000Z          5
# 5  2014-12-20T20:47:52.073000Z          6
# 'starships'
#                            name                            model  \
# 0                 CR90 corvette                    CR90 corvette
# 1                Star Destroyer  Imperial I-class Star Destroyer
# 2  Sentinel-class landing craft     Sentinel-class landing craft
# 3                    Death Star      DS-1 Orbital Battle Station
# 4             Millennium Falcon          YT-1300 light freighter
# 5                        Y-wing                       BTL Y-wing
# 6                        X-wing                      T-65 X-wing
# 7               TIE Advanced x1      Twin Ion Engine Advanced x1
# 8                      Executor  Executor-class star dreadnought
# 9               Rebel transport           GR-75 medium transport
#
#                     starship_class  \
# 0                         corvette
# 1                   Star Destroyer
# 2                    landing craft
# 3  Deep Space Mobile Battlestation
# 4                  Light freighter
# 5              assault starfighter
# 6                      Starfighter
# 7                      Starfighter
# 8                 Star dreadnought
# 9                 Medium transport
#
#                                         manufacturer cost_in_credits  length  \
# 0                  Corellian Engineering Corporation         3500000     150
# 1                                   Kuat Drive Yards       150000000   1,600
# 2            Sienar Fleet Systems, Cyngus Spaceworks          240000      38
# 3  Imperial Department of Military Research, Sien...   1000000000000  120000
# 4                  Corellian Engineering Corporation          100000   34.37
# 5                             Koensayr Manufacturing          134999      14
# 6                                  Incom Corporation          149999    12.5
# 7                               Sienar Fleet Systems         unknown     9.2
# 8                 Kuat Drive Yards, Fondor Shipyards      1143350000   19000
# 9                              Gallofree Yards, Inc.         unknown      90
#
#       crew passengers max_atmosphering_speed hyperdrive_rating MGLT  \
# 0   30-165        600                    950               2.0   60
# 1   47,060        n/a                    975               2.0   60
# 2        5         75                   1000               1.0   70
# 3  342,953    843,342                    n/a               4.0   10
# 4        4          6                   1050               0.5   75
# 5        2          0                 1000km               1.0   80
# 6        1          0                   1050               1.0  100
# 7        1          0                   1200               1.0  105
# 8  279,144      38000                    n/a               2.0   40
# 9        6         90                    650               4.0   20
#
#   cargo_capacity consumables  \
# 0        3000000      1 year
# 1       36000000     2 years
# 2         180000     1 month
# 3  1000000000000     3 years
# 4         100000    2 months
# 5            110      1 week
# 6            110      1 week
# 7            150      5 days
# 8      250000000     6 years
# 9       19000000    6 months
#
#                                                films  \
# 0  ["https://swapi.dev/api/films/1/", "https://sw...
# 1  ["https://swapi.dev/api/films/1/", "https://sw...
# 2                 ["https://swapi.dev/api/films/1/"]
# 3                 ["https://swapi.dev/api/films/1/"]
# 4  ["https://swapi.dev/api/films/1/", "https://sw...
# 5  ["https://swapi.dev/api/films/1/", "https://sw...
# 6  ["https://swapi.dev/api/films/1/", "https://sw...
# 7                 ["https://swapi.dev/api/films/1/"]
# 8  ["https://swapi.dev/api/films/2/", "https://sw...
# 9  ["https://swapi.dev/api/films/2/", "https://sw...
#
#                                               pilots  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  ["https://swapi.dev/api/people/13/", "https://...
# 5                                                 []
# 6  ["https://swapi.dev/api/people/1/", "https://s...
# 7                ["https://swapi.dev/api/people/4/"]
# 8                                                 []
# 9                                                 []
#
#                                    url                      created  \
# 0   https://swapi.dev/api/starships/2/  2014-12-10T14:20:33.369000Z
# 1   https://swapi.dev/api/starships/3/  2014-12-10T15:08:19.848000Z
# 2   https://swapi.dev/api/starships/5/  2014-12-10T15:48:00.586000Z
# 3   https://swapi.dev/api/starships/9/  2014-12-10T16:36:50.509000Z
# 4  https://swapi.dev/api/starships/10/  2014-12-10T16:59:45.094000Z
# 5  https://swapi.dev/api/starships/11/  2014-12-12T11:00:39.817000Z
# 6  https://swapi.dev/api/starships/12/  2014-12-12T11:19:05.340000Z
# 7  https://swapi.dev/api/starships/13/  2014-12-12T11:21:32.991000Z
# 8  https://swapi.dev/api/starships/15/  2014-12-15T12:31:42.547000Z
# 9  https://swapi.dev/api/starships/17/  2014-12-15T12:34:52.264000Z
#
#                         edited  unique_id
# 0  2014-12-20T21:23:49.867000Z          2
# 1  2014-12-20T21:23:49.870000Z          3
# 2  2014-12-20T21:23:49.873000Z          5
# 3  2014-12-20T21:26:24.783000Z          9
# 4  2014-12-20T21:23:49.880000Z         10
# 5  2014-12-20T21:23:49.883000Z         11
# 6  2014-12-20T21:23:49.886000Z         12
# 7  2014-12-20T21:23:49.889000Z         13
# 8  2014-12-20T21:23:49.893000Z         15
# 9  2014-12-20T21:23:49.895000Z         17
# 'vehicles'
#                           name                           model  \
# 0                 Sand Crawler                  Digger Crawler
# 1               T-16 skyhopper                  T-16 skyhopper
# 2             X-34 landspeeder                X-34 landspeeder
# 3           TIE/LN starfighter  Twin Ion Engine/Ln Starfighter
# 4                  Snowspeeder                 t-47 airspeeder
# 5                   TIE bomber                   TIE/sa bomber
# 6                        AT-AT   All Terrain Armored Transport
# 7                        AT-ST     All Terrain Scout Transport
# 8  Storm IV Twin-Pod cloud car               Storm IV Twin-Pod
# 9                   Sail barge      Modified Luxury Sail Barge
#
#             vehicle_class                                       manufacturer  \
# 0                 wheeled                        Corellia Mining Corporation
# 1           repulsorcraft                                  Incom Corporation
# 2           repulsorcraft                               SoroSuub Corporation
# 3             starfighter                               Sienar Fleet Systems
# 4              airspeeder                                  Incom corporation
# 5  space/planetary bomber                               Sienar Fleet Systems
# 6          assault walker  Kuat Drive Yards, Imperial Department of Milit...
# 7                  walker  Kuat Drive Yards, Imperial Department of Milit...
# 8           repulsorcraft                                      Bespin Motors
# 9              sail barge       Ubrikkian Industries Custom Vehicle Division
#
#   length cost_in_credits crew passengers max_atmosphering_speed  \
# 0  36.8           150000   46         30                     30
# 1  10.4            14500    1          1                   1200
# 2   3.4            10550    1          1                    250
# 3    6.4         unknown    1          0                   1200
# 4    4.5         unknown    2          0                    650
# 5    7.8         unknown    1          0                    850
# 6     20         unknown    5         40                     60
# 7      2         unknown    2          0                     90
# 8      7           75000    2          0                   1500
# 9     30          285000   26        500                    100
#
#   cargo_capacity      consumables  \
# 0          50000         2 months
# 1             50                0
# 2              5          unknown
# 3             65           2 days
# 4             10             none
# 5           none           2 days
# 6           1000          unknown
# 7            200             none
# 8             10            1 day
# 9        2000000  Live food tanks
#
#                                                films  \
# 0  ["https://swapi.dev/api/films/1/", "https://sw...
# 1                 ["https://swapi.dev/api/films/1/"]
# 2                 ["https://swapi.dev/api/films/1/"]
# 3  ["https://swapi.dev/api/films/1/", "https://sw...
# 4                 ["https://swapi.dev/api/films/2/"]
# 5  ["https://swapi.dev/api/films/2/", "https://sw...
# 6  ["https://swapi.dev/api/films/2/", "https://sw...
# 7  ["https://swapi.dev/api/films/2/", "https://sw...
# 8                 ["https://swapi.dev/api/films/2/"]
# 9                 ["https://swapi.dev/api/films/3/"]
#
#                                               pilots  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  ["https://swapi.dev/api/people/1/", "https://s...
# 5                                                 []
# 6                                                 []
# 7               ["https://swapi.dev/api/people/13/"]
# 8                                                 []
# 9                                                 []
#
#                                   url                      created  \
# 0   https://swapi.dev/api/vehicles/4/  2014-12-10T15:36:25.724000Z
# 1   https://swapi.dev/api/vehicles/6/  2014-12-10T16:01:52.434000Z
# 2   https://swapi.dev/api/vehicles/7/  2014-12-10T16:13:52.586000Z
# 3   https://swapi.dev/api/vehicles/8/  2014-12-10T16:33:52.860000Z
# 4  https://swapi.dev/api/vehicles/14/         2014-12-15T12:22:12Z
# 5  https://swapi.dev/api/vehicles/16/  2014-12-15T12:33:15.838000Z
# 6  https://swapi.dev/api/vehicles/18/  2014-12-15T12:38:25.937000Z
# 7  https://swapi.dev/api/vehicles/19/  2014-12-15T12:46:42.384000Z
# 8  https://swapi.dev/api/vehicles/20/  2014-12-15T12:58:50.530000Z
# 9  https://swapi.dev/api/vehicles/24/  2014-12-18T10:44:14.217000Z
#
#                         edited  unique_id
# 0  2014-12-20T21:30:21.661000Z          4
# 1  2014-12-20T21:30:21.665000Z          6
# 2  2014-12-20T21:30:21.668000Z          7
# 3  2014-12-20T21:30:21.670000Z          8
# 4  2014-12-20T21:30:21.672000Z         14
# 5  2014-12-20T21:30:21.675000Z         16
# 6  2014-12-20T21:30:21.677000Z         18
# 7  2014-12-20T21:30:21.679000Z         19
# 8  2014-12-20T21:30:21.681000Z         20
# 9  2014-12-20T21:30:21.684000Z         24
# 'species'
#              name average_height average_lifespan classification designation  \
# 0           Human            180              120         mammal    sentient
# 1           Droid            n/a       indefinite     artificial    sentient
# 2          Wookie            210              400         mammal    sentient
# 3          Rodian            170          unknown       sentient   reptilian
# 4            Hutt            300             1000      gastropod    sentient
# 5  Yoda's species             66              900         mammal    sentient
# 6      Trandoshan            200          unknown        reptile    sentient
# 7    Mon Calamari            160          unknown      amphibian    sentient
# 8            Ewok            100          unknown         mammal    sentient
# 9       Sullustan            180          unknown         mammal    sentient
#
#                                 eye_colors                hair_colors  \
# 0   brown, blue, green, hazel, grey, amber  blonde, brown, black, red
# 1                                      n/a                        n/a
# 2  blue, green, yellow, brown, golden, red               black, brown
# 3                                    black                        n/a
# 4                              yellow, red                        n/a
# 5                     brown, green, yellow               brown, white
# 6                           yellow, orange                       none
# 7                                   yellow                       none
# 8                            orange, brown        white, brown, black
# 9                                    black                       none
#
#    homeworld        language                        skin_colors  \
# 0        9.0  Galactic Basic  caucasian, black, asian, hispanic
# 1        NaN             n/a                                n/a
# 2       14.0      Shyriiwook                               gray
# 3       23.0   Galatic Basic                        green, blue
# 4       24.0         Huttese                  green, brown, tan
# 5       28.0  Galactic basic                      green, yellow
# 6       29.0            Dosh                       brown, green
# 7       31.0  Mon Calamarian          red, blue, brown, magenta
# 8        7.0         Ewokese                              brown
# 9       33.0       Sullutese                               pale
#
#                                               people  \
# 0  ["https://swapi.dev/api/people/66/", "https://...
# 1  ["https://swapi.dev/api/people/2/", "https://s...
# 2  ["https://swapi.dev/api/people/13/", "https://...
# 3               ["https://swapi.dev/api/people/15/"]
# 4               ["https://swapi.dev/api/people/16/"]
# 5               ["https://swapi.dev/api/people/20/"]
# 6               ["https://swapi.dev/api/people/24/"]
# 7               ["https://swapi.dev/api/people/27/"]
# 8               ["https://swapi.dev/api/people/30/"]
# 9               ["https://swapi.dev/api/people/31/"]
#
#                                                films  \
# 0  ["https://swapi.dev/api/films/1/", "https://sw...
# 1  ["https://swapi.dev/api/films/1/", "https://sw...
# 2  ["https://swapi.dev/api/films/1/", "https://sw...
# 3                 ["https://swapi.dev/api/films/1/"]
# 4  ["https://swapi.dev/api/films/1/", "https://sw...
# 5  ["https://swapi.dev/api/films/2/", "https://sw...
# 6                 ["https://swapi.dev/api/films/2/"]
# 7                 ["https://swapi.dev/api/films/3/"]
# 8                 ["https://swapi.dev/api/films/3/"]
# 9                 ["https://swapi.dev/api/films/3/"]
#
#                                  url                      created  \
# 0   https://swapi.dev/api/species/1/  2014-12-10T13:52:11.567000Z
# 1   https://swapi.dev/api/species/2/  2014-12-10T15:16:16.259000Z
# 2   https://swapi.dev/api/species/3/  2014-12-10T16:44:31.486000Z
# 3   https://swapi.dev/api/species/4/  2014-12-10T17:05:26.471000Z
# 4   https://swapi.dev/api/species/5/  2014-12-10T17:12:50.410000Z
# 5   https://swapi.dev/api/species/6/  2014-12-15T12:27:22.877000Z
# 6   https://swapi.dev/api/species/7/  2014-12-15T13:07:47.704000Z
# 7   https://swapi.dev/api/species/8/  2014-12-18T11:09:52.263000Z
# 8   https://swapi.dev/api/species/9/  2014-12-18T11:22:00.285000Z
# 9  https://swapi.dev/api/species/10/  2014-12-18T11:26:20.103000Z
#
#                         edited  unique_id
# 0  2014-12-20T21:36:42.136000Z          1
# 1  2014-12-20T21:36:42.139000Z          2
# 2  2014-12-20T21:36:42.142000Z          3
# 3  2014-12-20T21:36:42.144000Z          4
# 4  2014-12-20T21:36:42.146000Z          5
# 5  2014-12-20T21:36:42.148000Z          6
# 6  2014-12-20T21:36:42.151000Z          7
# 7  2014-12-20T21:36:42.153000Z          8
# 8  2014-12-20T21:36:42.155000Z          9
# 9  2014-12-20T21:36:42.157000Z         10
# 'planets'
#         name diameter rotation_period orbital_period  \
# 0   Tatooine    10465              23            304
# 1   Alderaan    12500              24            364
# 2   Yavin IV    10200              24           4818
# 3       Hoth     7200              23            549
# 4    Dagobah     8900              23            341
# 5     Bespin   118000              12           5110
# 6      Endor     4900              18            402
# 7      Naboo    12120              26            312
# 8  Coruscant    12240              24            368
# 9     Kamino    19720              27            463
#
#                                   gravity     population              climate  \
# 0                              1 standard         200000                 arid
# 1                              1 standard     2000000000            temperate
# 2                              1 standard           1000  temperate, tropical
# 3                            1.1 standard        unknown               frozen
# 4                                     N/A        unknown                murky
# 5  1.5 (surface), 1 standard (Cloud City)        6000000            temperate
# 6                           0.85 standard       30000000            temperate
# 7                              1 standard     4500000000            temperate
# 8                              1 standard  1000000000000            temperate
# 9                              1 standard     1000000000            temperate
#
#                                     terrain surface_water  \
# 0                                    desert             1
# 1                     grasslands, mountains            40
# 2                       jungle, rainforests             8
# 3        tundra, ice caves, mountain ranges           100
# 4                            swamp, jungles             8
# 5                                 gas giant             0
# 6                 forests, mountains, lakes             8
# 7  grassy hills, swamps, forests, mountains            12
# 8                      cityscape, mountains       unknown
# 9                                     ocean           100
#
#                                            residents  \
# 0  ["https://swapi.dev/api/people/1/", "https://s...
# 1  ["https://swapi.dev/api/people/5/", "https://s...
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5               ["https://swapi.dev/api/people/26/"]
# 6               ["https://swapi.dev/api/people/30/"]
# 7  ["https://swapi.dev/api/people/3/", "https://s...
# 8  ["https://swapi.dev/api/people/34/", "https://...
# 9  ["https://swapi.dev/api/people/22/", "https://...
#
#                                                films  \
# 0  ["https://swapi.dev/api/films/1/", "https://sw...
# 1  ["https://swapi.dev/api/films/1/", "https://sw...
# 2                 ["https://swapi.dev/api/films/1/"]
# 3                 ["https://swapi.dev/api/films/2/"]
# 4  ["https://swapi.dev/api/films/2/", "https://sw...
# 5                 ["https://swapi.dev/api/films/2/"]
# 6                 ["https://swapi.dev/api/films/3/"]
# 7  ["https://swapi.dev/api/films/3/", "https://sw...
# 8  ["https://swapi.dev/api/films/3/", "https://sw...
# 9                 ["https://swapi.dev/api/films/5/"]
#
#                                  url                      created  \
# 0   https://swapi.dev/api/planets/1/  2014-12-09T13:50:49.641000Z
# 1   https://swapi.dev/api/planets/2/  2014-12-10T11:35:48.479000Z
# 2   https://swapi.dev/api/planets/3/  2014-12-10T11:37:19.144000Z
# 3   https://swapi.dev/api/planets/4/  2014-12-10T11:39:13.934000Z
# 4   https://swapi.dev/api/planets/5/  2014-12-10T11:42:22.590000Z
# 5   https://swapi.dev/api/planets/6/  2014-12-10T11:43:55.240000Z
# 6   https://swapi.dev/api/planets/7/  2014-12-10T11:50:29.349000Z
# 7   https://swapi.dev/api/planets/8/  2014-12-10T11:52:31.066000Z
# 8   https://swapi.dev/api/planets/9/  2014-12-10T11:54:13.921000Z
# 9  https://swapi.dev/api/planets/10/  2014-12-10T12:45:06.577000Z
#
#                         edited  unique_id
# 0  2014-12-20T20:58:18.411000Z          1
# 1  2014-12-20T20:58:18.420000Z          2
# 2  2014-12-20T20:58:18.421000Z          3
# 3  2014-12-20T20:58:18.423000Z          4
# 4  2014-12-20T20:58:18.425000Z          5
# 5  2014-12-20T20:58:18.427000Z          6
# 6  2014-12-20T20:58:18.429000Z          7
# 7  2014-12-20T20:58:18.430000Z          8
# 8  2014-12-20T20:58:18.432000Z          9
# 9  2014-12-20T20:58:18.434000Z         10

# %% [markdown]
# ## 1. Required SQL analysis

# %% [markdown]
# ### 1.1 What's the distribution of citizens across different planets
# - Requirement: `1 request with INNER`
# - Explanation: By using INNER JOIN, we only return people that have a known homeworld.

# %%
pd.read_sql(
    '''
    select 
        p2.name as planet_name,
        count(p1.name) as people_count
    from people p1
    inner join 
        planets p2
    on p1.homeworld = p2.unique_id
    group by
        p2.name
    order by 
        people_count desc
    ''', 
    conn
)
# Out:
#        planet_name  people_count
# 0            Naboo            11
# 1         Tatooine            10
# 2          unknown             5
# 3           Kamino             3
# 4        Coruscant             3
# 5         Alderaan             3
# 6           Ryloth             2
# 7           Mirial             2
# 8         Kashyyyk             2
# 9         Corellia             2
# 10           Zolan             1
# 11         Vulpter             1
# 12          Utapau             1
# 13          Umbara             1
# 14            Tund             1
# 15         Troiken             1
# 16       Trandosha             1
# 17        Toydaria             1
# 18         Sullust             1
# 19         Stewjon             1
# 20         Socorro             1
# 21           Skako             1
# 22           Shili             1
# 23         Serenno             1
# 24           Rodia             1
# 25         Quermia             1
# 26            Ojom             1
# 27       Nal Hutta             1
# 28      Muunilinst             1
# 29        Mon Cala             1
# 30       Malastare             1
# 31           Kalee             1
# 32        Iridonia             1
# 33         Iktotch             1
# 34      Haruun Kal             1
# 35     Glee Anselm             1
# 36        Geonosis             1
# 37          Eriadu             1
# 38           Endor             1
# 39           Dorin             1
# 40        Dathomir             1
# 41    Concord Dawn             1
# 42       Chandrila             1
# 43        Champala             1
# 44           Cerea             1
# 45  Cato Neimoidia             1
# 46      Bestine IV             1
# 47          Bespin             1
# 48     Aleen Minor             1

# %% [markdown]
# ### 1.2 What's the distribution of species across different planets
# - Requirement: `1 request with LEFT`
# - Explanation: By using LEFT JOIN, we return species regardless of whether their homeworld is known.

# %%
pd.read_sql(
    '''
    select 
        p2.name as planet_name,
        count(s.name) as species_count
    from species s
    left join 
        planets p2
    on s.homeworld = p2.unique_id
    group by
        p2.name
    order by 
        species_count desc
    ''', 
    conn
)
# Out:
#        planet_name  species_count
# 0          unknown              1
# 1            Zolan              1
# 2          Vulpter              1
# 3           Utapau              1
# 4             Tund              1
# 5          Troiken              1
# 6        Trandosha              1
# 7         Toydaria              1
# 8          Tholoth              1
# 9          Sullust              1
# 10           Skako              1
# 11           Shili              1
# 12          Ryloth              1
# 13           Rodia              1
# 14         Quermia              1
# 15            Ojom              1
# 16       Nal Hutta              1
# 17           Naboo              1
# 18      Muunilinst              1
# 19        Mon Cala              1
# 20          Mirial              1
# 21       Malastare              1
# 22        Kashyyyk              1
# 23          Kamino              1
# 24           Kalee              1
# 25        Iridonia              1
# 26         Iktotch              1
# 27     Glee Anselm              1
# 28        Geonosis              1
# 29           Endor              1
# 30           Dorin              1
# 31       Coruscant              1
# 32        Champala              1
# 33           Cerea              1
# 34  Cato Neimoidia              1
# 35     Aleen Minor              1
# 36            None              1

# %% [markdown]
# ### 1.3 What are the average costs, passengers, length for each vehicle class.
# - Requirement: `1 request with GROUP BY`
# - Explanation: By using GROUP BY, we could get the relevant values divided by vehicle class.

# %%
pd.read_sql(
    '''
        select 
            vehicle_class,
            group_concat(model) as model,
            round(avg(cost_in_credits),2) as average_cost,
            round(avg(passengers)) as average_passengers,
            round(avg(length), 2) as average_length,
            count(model) as model_count
        from 
            vehicles
        group by
            vehicle_class
        order by 
            average_cost desc
    ''', 
    conn
)
# Out:
#                 vehicle_class  \
# 0                  sail barge
# 1               landing craft
# 2              wheeled walker
# 3                     wheeled
# 4                  droid tank
# 5               repulsorcraft
# 6           droid starfighter
# 7                 air speeder
# 8                  airspeeder
# 9                      walker
# 10  repulsorcraft cargo skiff
# 11                    speeder
# 12                  transport
# 13                  submarine
# 14                starfighter
# 15     space/planetary bomber
# 16                    gunship
# 17      fire suppression ship
# 18             assault walker
#
#                                                 model  average_cost  \
# 0                          Modified Luxury Sail Barge     285000.00
# 1                                C-9979 landing craft     200000.00
# 2      Tsmeu-6 personal wheel bike,HAVw A6 Juggernaut     182500.00
# 3                                      Digger Crawler     150000.00
# 4               NR-N99 Persuader-class droid enforcer      49000.00
# 5   T-16 skyhopper,X-34 landspeeder,Storm IV Twin-...      35185.71
# 6                                         tri-fighter      20000.00
# 7                         Raddaugh Gnasp fluttercraft      14750.00
# 8   t-47 airspeeder,Koro-2 Exodrive airspeeder,XJ-...      14425.00
# 9   All Terrain Scout Transport,All Terrain Tactic...      10000.00
# 10                                          Bantha-II       8000.00
# 11  74-Z speeder bike,FC-20 speeder bike,Flitknot ...       6666.67
# 12                Sheathipede-class transport shuttle          0.00
# 13                                    Tribubble bongo          0.00
# 14  Twin Ion Engine/Ln Starfighter,Twin Ion Engine...          0.00
# 15                                      TIE/sa bomber          0.00
# 16  Low Altitude Assault Transport/infrantry,Low A...          0.00
# 17                           Fire suppression speeder          0.00
# 18                      All Terrain Armored Transport          0.00
#
#     average_passengers  average_length  model_count
# 0                500.0           30.00            1
# 1                284.0          210.00            1
# 2                151.0           26.45            2
# 3                 30.0           36.80            1
# 4                  4.0           10.96            1
# 5                 17.0            9.60            7
# 6                  0.0            5.40            1
# 7                  0.0            7.00            1
# 8                  1.0            8.95            5
# 9                 17.0           39.60            4
# 10                16.0            9.50            1
# 11                 0.0            2.17            3
# 12                 6.0           20.00            1
# 13                 2.0           15.00            1
# 14                 0.0            7.33            4
# 15                 0.0            7.80            1
# 16                15.0           23.11            2
# 17                 0.0            0.00            1
# 18                40.0           20.00            1

# %% [markdown]
# ### 1.4 Find out manufactures of starships who could design a passenger capacity over 50
# - Requirement: `1 request with HAVING`
# - Explanation: By grouping the data by manufacturer, we could use HAVING to filter out manufacutres that has the capability to desgin starships with the average passenger capcity over 50.

# %%
pd.read_sql(
    '''
        select 
            manufacturer,
            cast(avg(passengers) as int) as average_passengers
        from 
            starships
        group by 
            manufacturer
        having 
            average_passengers>50
        order by 
            average_passengers desc
            
    ''', 
    conn
)
# Out:
#                                          manufacturer  average_passengers
# 0                          Hoersch-Kessel Drive, Inc.              139000
# 1   Rendili StarDrive, Free Dac Volunteers Enginee...               48247
# 2                  Kuat Drive Yards, Fondor Shipyards               38000
# 3                                   Botajef Shipyards               30000
# 4                           Rothana Heavy Engineering               16000
# 5           Kuat Drive Yards, Allanteen Six shipyards                2000
# 6                              Mon Calamari shipyards                1200
# 7   Imperial Department of Military Research, Sien...                 843
# 8                   Corellian Engineering Corporation                 207
# 9                               Gallofree Yards, Inc.                  90
# 10            Sienar Fleet Systems, Cyngus Spaceworks                  75

# %% [markdown]
# ### 1.5 Find out the oldest person in the Star Wars
# - Requirement: `1 request with CTE`
# - Explaination:
#     - By creating a temporary table, we conver the string `19BBY`, 19 years before the battle of yavin, to 19. And we write another query to return the oldest person's name and age.
#     - Before implementing queries, we have checked no one is born ABY.

# %%
pd.read_sql(
    '''
        select
            count(*) as aby_count
        from
            people 
        where birth_year like '%ABY';
    ''', 
    conn
)
# Out:
#    aby_count
# 0          0

# %%
pd.read_sql(
    '''
        with cleaned_birthyear as (
            select 
                name,
                cast(replace(birth_year, 'BBY', '') as integer) as birth_year_bby
            from 
                people
            where 
                birth_year != "unknown"
        )

        select 
            name,
            max(birth_year_bby) as birth_year
        from
            cleaned_birthyear
    ''', 
    conn
)
# Out:
#    name  birth_year
# 0  Yoda         896

# %%
# Out:
#    COUNT(*)
# 0         0
